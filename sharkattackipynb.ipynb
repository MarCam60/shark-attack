# %%
from os import read
import pandas as pd
import numpy as np
shark_df = pd.read_csv("/content/attacks.csv", encoding='cp1252')
shark_df

# %% [markdown]
# De Top 10
# Hieronder vind je de top 10 gevaarlijkste haaiensoorten voor mensen. Ze staan van de minst gevaarlijke tot en met de meest gevaarlijkste genoteerd. Voor nog meer informatie over de specifieke haai scrol je gewoon verder naar beneden.
# 10. De Grote hamerhaai:
# 9.  De zwartpunthaai:
# 8.  De zandtijgerhaai:
# 7.  De blauwe haai:
# 6.  De makreelhaai:
# .
# 5.  De witpunthaai:
# 4.  De koperhaai:
# 3.  De stierhaai:
# 2.  De tijgerhaai:
# 1.  De witte haai:

# %%
shark_df.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
shark_df.columns = shark_df.columns.str.strip()
shark_df.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
shark_df.Activity.unique()
# Out:
# array(['Paddling', 'Standing', 'Surfing', ...,
#        'Crew swimming alongside their anchored ship',
#        '4 men were bathing', 'Wreck of  large double sailing canoe'],
#       dtype=object)

# %%
Activity_df = shark_df

# %%
Activity_df.Activity.value_counts().plot(kind = "pie")

# %%
shark_df.Age.unique()
# Out:
# array(['57', '11', '48', nan, '18', '52', '15', '12', '32', '10', '21',
#        '34', '30', '60', '33', '29', '54', '41', '37', '56', '19', '25',
#        '69', '38', '55', '35', '46', '45', '14', '40s', '28', '20', '24',
#        '26', '49', '22', '7', '31', '17', '40', '13', '42', '3', '8',
#        '50', '16', '82', '73', '20s', '68', '51', '39', '58', 'Teen',
#        '47', '61', '65', '36', '66', '43', '60s', '9', '72', '59', '6',
#        '27', '64', '23', '71', '44', '62', '63', '70', '18 months', '53',
#        '30s', '50s', 'teen', '77', '74', '28 & 26', '5', '86', '18 or 20',
#        '12 or 13', '46 & 34', '28, 23 & 30', 'Teens', '36 & 26',
#        '8 or 10', '84', '\xa0 ', ' ', '30 or 36', '6½', '21 & ?', '75',
#        '33 or 37', 'mid-30s', '23 & 20', ' 30', '7      &    31', ' 28',
#        '20?', "60's", '32 & 30', '16 to 18', '87', '67', 'Elderly',
#        'mid-20s', 'Ca. 33', '74 ', '45 ', '21 or 26', '20 ', '>50',
# ...

# %%
def set_age(value):
  try:
    return int(value)
  except:
    return np.nan
set_age("Young")
# Out:
# nan

# %%
new_age = shark_df.Age.apply(set_age)
print (new_age.unique())
print(len(new_age[new_age<12]))
print (len(new_age))
# Out:
# [57. 11. 48. nan 18. 52. 15. 12. 32. 10. 21. 34. 30. 60. 33. 29. 54. 41.
#  37. 56. 19. 25. 69. 38. 55. 35. 46. 45. 14. 28. 20. 24. 26. 49. 22.  7.
#  31. 17. 40. 13. 42.  3.  8. 50. 16. 82. 73. 68. 51. 39. 58. 47. 61. 65.
#  36. 66. 43.  9. 72. 59.  6. 27. 64. 23. 71. 44. 62. 63. 70. 53. 77. 74.
#   5. 86. 84. 75. 87. 67.  1. 81. 78.]
# 206
# 25723

# %%
shark_df.Age.count()
new_age.count()
# Out:
# 3369

# %% [markdown]
# Er zijn ongeveer 215( 206 plus 9 kinderen onder de twaalf jaar en in totaal 3369 mensen die getroffen zijn door een haai.

# %%
shark_df.Type.unique()
# Out:
# array(['Boating', 'Unprovoked', 'Invalid', 'Provoked', 'Questionable',
#        'Sea Disaster', nan, 'Boat', 'Boatomg'], dtype=object)

# %%
shark_df.Species.unique()
# Out:
# array(['White shark', nan, '2 m shark', ..., "12' tiger shark",
#        'Blue pointers',
#        'Said to involve a grey nurse shark that leapt out of the water and  seized the boy but species identification is questionable'],
#       dtype=object)
